# %% [markdown]
# # Import libraries

# %%
import os
import cv2
import time
import shutil
import random
import numpy as np
import matplotlib.pyplot as plt

### Other dependencies ###
from PIL import Image
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

### Tensorflow dependencies ###
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy

### Some constants ###
input_dim = 12 # 48
# weights_dir = 'road_signs_1'
weights_dir = 'road_signs'
pnet_tensorboard_logdir = '../pnet_logs'
rnet_tensorboard_logdir = '../rnet_logs'
onet_tensorboard_logdir = '../onet_logs'

pnet_weights = f'../weights/{weights_dir}/pnet.weights.hdf5'
rnet_weights = f'../weights/{weights_dir}/rnet.weights.hdf5'
onet_weights = f'../weights/{weights_dir}/onet.weights.hdf5'

if(not os.path.exists(f'weights/{weights_dir}')):
    print('[INFO] Created weight directory ...')
    os.mkdir(f'../weights/{weights_dir}')
    
if(os.path.exists(pnet_tensorboard_logdir)):
    print('[INFO] Clearing P-Net log directory ... ')
    shutil.rmtree(pnet_tensorboard_logdir)

if(os.path.exists(rnet_tensorboard_logdir)):
    print('[INFO] Clearing R-Net log directory ... ')
    shutil.rmtree(rnet_tensorboard_logdir)

if(os.path.exists(onet_tensorboard_logdir)):
    print('[INFO] Clearing O-Net log directory ... ')
    shutil.rmtree(onet_tensorboard_logdir)
    
epochs = 100 # 500
batch_size = 16
pnet_tensorboard = TensorBoard(log_dir=pnet_tensorboard_logdir)
pnet_checkpoint = ModelCheckpoint(pnet_weights, save_weights_only=True)
pnet_callbacks = [pnet_tensorboard, pnet_checkpoint]

rnet_tensorboard = TensorBoard(log_dir=rnet_tensorboard_logdir)
rnet_checkpoint = ModelCheckpoint(rnet_weights, save_weights_only=True)
rnet_callbacks = [rnet_tensorboard, rnet_checkpoint]

onet_tensorboard = TensorBoard(log_dir=onet_tensorboard_logdir)
onet_checkpoint = ModelCheckpoint(onet_weights, save_weights_only=True)
onet_early_stop1 = EarlyStopping(monitor='val_probability_loss', patience=15, verbose=1)
onet_early_stop2 = EarlyStopping(monitor='val_bbox_regression_loss', patience=15, verbose=1)
onet_callbacks = [onet_tensorboard, onet_checkpoint]

train_dir = "./road_signs/images"
test_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TestIJCNN2013/TestIJCNN2013Download"

# %% [markdown]
# # Load and explore dataset

# %%
def load_raw_dataset(dataset_dir, gt_file, delimiter=';', max_n_samples=3000):
    '''
        This function will take in a dataset directory with ppm images (according to the DTSDB dataset)
        then it will return a list where each element is a list of 3 items. First item is the image, the
        second item is the bounding box and the last is the class ID.
        
        Params :
            @dataset_dir : Dataset directory.
            @gt_file : The file that consists of ground truth annotation in the format
            <img_pth>;<left>;<top>;<right>;<bottom>;<class_idx>.
            @delimiter : The separator of each item in each line of the ground truth file
            
        Returns :
            raw_dataset : list of elements [<cv2_img>, <gt_bbox>, <class_idx>]
    '''
    gt_abs_path = os.path.join(dataset_dir, gt_file)
    class_ids = {}
    lines = open(gt_abs_path, 'r').readlines()
    
    print('[INFO] From images to ground truth ... ')
    images_to_gt = [[x.strip().split(delimiter)[0],   # Image path
                     x.strip().split(delimiter)[1:5], # Bbox regression ground truth
                     x.strip().split(delimiter)[5]]   # The class index
                    for x in lines]
    
    print('[INFO] Converting to raw dataset ... ')
    raw_dataset = [[cv2.cvtColor(cv2.imread(os.path.join(dataset_dir, x[0])), cv2.COLOR_BGR2RGB),
                    np.array(x[1]).astype('int'),
                    x[2]] 
                  for x in images_to_gt[:max_n_samples]]
    
    print(f'[INFO] {len(raw_dataset)} samples loaded ... ')
    
    return raw_dataset
    
# raw_dataset = load_raw_dataset(train_dir, 'gt.txt')

# ### Visualize sample data ###
# img = raw_dataset[1][0].copy()
# bbox = raw_dataset[1][1]
# x1, y1, x2, y2 = bbox
# img = cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ### Generating negative samples (samples without traffic signs)

# %%
def generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(48, 48)):
    '''
        This function will generate croppings of fixed size without any traffic sign
        and return those croppings with dummy bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @crop_size : The fixed cropping size
            
        Return:
            neg_samples : A list in format [<crop_img>,<dummy_bbox>,0]
    '''
    neg_samples = []
    for img, bbox, class_id in raw_dataset:
        for i in range(frame_per_img):
            height, width = img.shape[:2]
            x1, y1, x2, y2 = bbox
            range_x = ((0, max(x1 - crop_size[0], 0)), (min(x2 + crop_size[0], width), width))
            range_y = ((0, max(y1 - crop_size[1], 0)), (min(y2 + crop_size[1], height), height))

            ### Generate a random x,y coordinates ###
            x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                               random.randint(range_x[1][0], range_x[1][1])])
            y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                               random.randint(range_y[1][0], range_y[1][1])])

            # regenerate if cropping does not satisfy the size requirements
            while(width - x < crop_size[0] or height - y < crop_size[1]):
                x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                               random.randint(range_x[1][0], range_x[1][1])])
                y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                               random.randint(range_y[1][0], range_y[1][1])])

            crop = img[y:y+crop_size[1], x:x+crop_size[0]]
            neg_samples.append([crop, np.array([0,0,0,0]), 0])
        
    print(f'[INFO] {len(neg_samples)} negative samples generated ... ')
    return np.array(neg_samples)

# neg_samples = generate_neg_samples(raw_dataset, crop_size=(input_dim,input_dim))
# plt.imshow(neg_samples[1][0].copy())
# plt.show()

# %% [markdown]
# ### Generate positive samples (samles with traffic signs)

# %%
def generate_pos_samples(raw_dataset, pad_range=(10, 100), frame_per_img=4, img_size=48):
    '''
        This function will generate croppings with traffic signs
        and return those croppings with bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @pad_range : The pad range around the ground truth bounding box
            
        Return:
            pos_samples : A list in format [<crop_img>,<bbox>,1]
    '''
    pos_samples = []
    for img, bbox, class_id in raw_dataset:
        for i in range(frame_per_img):
            height, width = img.shape[:2]
            x1, y1, x2, y2 = bbox
            pad_x1 = min(x1, random.randint(pad_range[0], pad_range[1]))
            pad_x2 = min(width - x2, random.randint(pad_range[0], pad_range[1]))
            pad_y1 = min(y1, random.randint(pad_range[0], pad_range[1]))
            pad_y2 = min(height - y2, random.randint(pad_range[0], pad_range[1]))

            crop = img[y1 - pad_y1:y2 + pad_y2, x1 - pad_x1:x2 + pad_x2]
            h, w = crop.shape[:2]

            gt = np.array([pad_x1, pad_y1, pad_x1 + x2 - x1, pad_y1 + y2 - y1])
            gt[2] = gt[2] - gt[0] # Calculates width
            gt[3] = gt[3] - gt[1] # Calculates height
            gt = np.multiply(gt, np.array([1/w, 1/h, 1/w, 1/h])).astype('float32')

            crop = cv2.resize(crop, (img_size, img_size))
            pos_samples.append([crop, gt, class_id])
        
    print(f'[INFO] {len(pos_samples)} positive samples generated ... ')
    return np.array(pos_samples)

# pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 15), img_size=input_dim)

# img, gt, label = pos_samples[6]
# img = img.copy()
# h, w = img.shape[:2]
# x1, y1, w, h = np.multiply(gt, np.array([w,h,w,h])).astype('int')

# img = cv2.rectangle(img, (x1, y1), (x1+w, y1+h), 2)
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ### Combine negative and positive samples to form training dataset

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(input_dim,input_dim))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 15), frame_per_img=4, img_size=input_dim)
pos_samples[:, 2] = 1.0
# pos_samples[:,2] = LabelEncoder().fit_transform(pos_samples[:, 2])
# pos_samples[:,2] += 1

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-77fd9c2a21b4> in <module>
#       1 # Generate raw data from firectory
# ----> 2 raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
#       3 neg_samples = generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(input_dim,input_dim))
#       4 pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 15), frame_per_img=4, img_size=input_dim)
#       5 pos_samples[:, 2] = 1.0
#
# <ipython-input-2-33055d0368d8> in load_raw_dataset(dataset_dir, gt_file, delimiter, max_n_samples)
#      16     gt_abs_path = os.path.join(dataset_dir, gt_file)
#      17     class_ids = {}
# ---> 18     lines = open(gt_abs_path, 'r').readlines()
#      19
#      20     print('[INFO] From images to ground truth ... ')
#
# FileNotFoundError: [Errno 2] No such file or directory: './road_signs/images/gt.txt'

# %% [markdown]
# # Implement P-Net architecture

# %%
def conv_block(in_filters, out_filters, kernel_size=3, batch_norm=False):
    inputs = Input(shape=(None, None, in_filters))
    p_layer = Conv2D(out_filters, kernel_size=kernel_size, strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(inputs)
    if(batch_norm) : p_layer = BatchNormalization()(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
        
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)
    
    block = Model(inputs = inputs, outputs=p_layer)
    return block

def build_pnet_model(input_shape=None, batch_norm=True, dropout=False, n_classes=2, activation='relu'):
    if(input_shape is not None):
        if(input_shape not in [12, 24, 48, 112, 224]):
            raise Exception('Input shape must be in 12, 24, 48')
    
    inputs = Input(shape=(None, None, 3))
    p_layer = conv_block(3, 10, kernel_size=3, batch_norm=batch_norm)(inputs)
    
    if(input_shape is not None):
        if(input_shape >= 24):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)
    
    if(input_shape is not None):
        if(input_shape >= 48):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)
            
    if(input_shape is not None):
        if(input_shape >= 112):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)

    p_layer = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
        
    p_layer = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    if(dropout) : p_layer = Dropout(0.5)(p_layer)

    p_layer_out1 = Conv2D(n_classes, kernel_size=(1, 1), strides=(2, 2))(p_layer)
    p_layer_out1 = Softmax(axis=3, name='probability')(p_layer_out1)
    p_layer_out2 = Conv2D(4, kernel_size=(1, 1), strides=(2, 2), activation='sigmoid', name='bbox_regression')(p_layer)

    p_net = Model(inputs, [p_layer_out1, p_layer_out2], name='P-Net')

    return p_net


### GIoU formula ###
def GIoU(bboxes_1, bboxes_2, regularization=False):
    # 1. calulate intersection over union
    area_1 = (bboxes_1[..., 2] - bboxes_1[..., 0]) * (bboxes_1[..., 3] - bboxes_1[..., 1])
    area_2 = (bboxes_2[..., 2] - bboxes_2[..., 0]) * (bboxes_2[..., 3] - bboxes_2[..., 1])
    
    intersection_wh = tf.minimum(bboxes_1[:, :, 2:], bboxes_2[:, :, 2:]) - tf.maximum(bboxes_1[:, :, :2], bboxes_2[:, :, :2])
    intersection_wh = tf.maximum(intersection_wh, 0)
    
    intersection = intersection_wh[..., 0] * intersection_wh[..., 1]
    union = (area_1 + area_2) - intersection
    
    ious = intersection / tf.maximum(union, 1e-10)

    # 2. (C - (A U B))/C
    C_wh = tf.maximum(bboxes_1[..., 2:], bboxes_2[..., 2:]) - tf.minimum(bboxes_1[..., :2], bboxes_2[..., :2])
    C_wh = tf.maximum(C_wh, 0.0)
    C = C_wh[..., 0] * C_wh[..., 1]
    
    # 3. Additional regularization - to preserve aspect ratio
    lambda_ = 2e-4
    w_reg = lambda_ * K.binary_crossentropy(bboxes_1[..., 2], bboxes_2[...,2])
    h_reg = lambda_ * K.binary_crossentropy(bboxes_1[..., 3], bboxes_2[...,3])
    
    giou = ious - (C - union) / tf.maximum(C, 1e-10)
    if(regularization):
        giou += 0.5 * (w_reg + h_reg)
        
    return giou 

n_classes = 2# train_labels.shape[3]
pnet = build_pnet_model(input_shape=input_dim, batch_norm=True, dropout=True,
                        n_classes=n_classes)
print(pnet(tf.random.normal((1,input_dim,input_dim,3)))[1].shape)
print(pnet.summary())
# Out:
# (1, 1, 1, 4)
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# functional_1 (Functional)       (None, None, None, 1 330         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 1 1456        functional_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, None, None, 1 16          conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 4640        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, None, None, 3 32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 3 0           p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 2 66          dropout[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout[0][0]
# ==================================================================================================
# Total params: 6,672
# Trainable params: 6,652
# Non-trainable params: 20
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Start training P-Net

# %%
losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() # MeanSquaredError(reduction=tf.keras.losses.Reduction.AUTO)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

if(os.path.exists(pnet_weights)):
    print('[INFO] Loading P-Net pretrained weights ...')
    pnet.load_weights(pnet_weights)
pnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})

# %%
history = pnet.fit(train_images, y, epochs=epochs, batch_size=batch_size, validation_split=0.2, callbacks=pnet_callbacks)
print('[INFO] Training halted, plotting training history ... ')

history = history.history
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
ax[0].plot(history['probability_loss'], color='orange', label='Training')
ax[0].plot(history['val_probability_loss'], color='blue', label='Validation')

ax[1].plot(history['bbox_regression_loss'], color='orange', label='Training')
ax[1].plot(history['val_bbox_regression_loss'], color='blue', label='Validation')

ax[0].legend()
ax[0].set_title('Classification losses')

ax[1].legend()
ax[1].set_title('BBox regression losses')

plt.savefig('PNet_training_result.png')
plt.show()

# %% [markdown]
# # Start training R-Net

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=5, crop_size=(input_dim*2,input_dim*2))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(10, 30), frame_per_img=4, img_size=input_dim*2)
pos_samples[:, 2] = 1.0
# pos_samples[:,2] = LabelEncoder().fit_transform(pos_samples[:, 2])
# pos_samples[:,2] += 1

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() 
    # 'bbox_regression' : MeanSquaredError(reduction=tf.keras.losses.Reduction.AUTO)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

rnet = build_pnet_model(input_shape=input_dim*2, batch_norm=True, dropout=True, n_classes=n_classes)
print(rnet.summary())

if(os.path.exists(rnet_weights)):
    print('[INFO] Loading R-Net pretrained weights ...')
    rnet.load_weights(rnet_weights)

rnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})

history = rnet.fit(train_images, y, epochs=epochs, batch_size=batch_size, callbacks=rnet_callbacks, validation_split=0.2)
print('[INFO] Training halted, plotting training history ... ')

history = history.history
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
ax[0].plot(history['probability_loss'], color='orange', label='Training')
ax[0].plot(history['val_probability_loss'], color='blue', label='Validation')
""
ax[1].plot(history['bbox_regression_loss'], color='orange', label='Training')
ax[1].plot(history['val_bbox_regression_loss'], color='blue', label='Validation')

ax[0].legend()
ax[0].set_title('Classification losses')

ax[1].legend()
ax[1].set_title('BBox regression losses')

plt.savefig('RNet_training_result.png')
plt.show()
# Out:
# [INFO] From images to ground truth ...
# [INFO] Converting to raw dataset ...
# [INFO] 1244 samples loaded ...
# [INFO] 6220 negative samples generated ...
# <ipython-input-3-223f64bb23c3>:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(neg_samples)
# <ipython-input-4-280b28c2d059>:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pos_samples)
# [INFO] 4976 positive samples generated ...
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# model_5 (Functional)            (None, None, None, 1 330         input_9[0][0]
# __________________________________________________________________________________________________
# model_6 (Functional)            (None, None, None, 1 960         model_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 1456        model_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, None, None, 1 16          conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 3 4640        p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, None, None, 3 32          conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, None, None, 3 0           p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 66          dropout_3[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout_3[0][0]
# ==================================================================================================
# Total params: 7,632
# Trainable params: 7,592
# Non-trainable params: 40
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 560/560 [==============================] - 9s 14ms/step - loss: 2.5108 - probability_loss: 0.7762 - bbox_regression_loss: 1.7250 - probability_accuracy: 0.4673 - val_loss: 2.3866 - val_probability_loss: 0.6381 - val_bbox_regression_loss: 1.7389 - val_probability_accuracy: 0.5192
# Epoch 2/100
# 560/560 [==============================] - 8s 14ms/step - loss: 2.3678 - probability_loss: 0.6466 - bbox_regression_loss: 1.7115 - probability_accuracy: 0.5754 - val_loss: 2.2604 - val_probability_loss: 0.5528 - val_bbox_regression_loss: 1.6981 - val_probability_accuracy: 0.7482
# Epoch 3/100
# 560/560 [==============================] - 8s 13ms/step - loss: 2.2404 - probability_loss: 0.5698 - bbox_regression_loss: 1.6609 - probability_accuracy: 0.7079 - val_loss: 2.0291 - val_probability_loss: 0.4825 - val_bbox_regression_loss: 1.5370 - val_probability_accuracy: 0.8504
# Epoch 4/100
# 560/560 [==============================] - 8s 14ms/step - loss: 2.0904 - probability_loss: 0.5230 - bbox_regression_loss: 1.5578 - probability_accuracy: 0.7654 - val_loss: 1.8364 - val_probability_loss: 0.4243 - val_bbox_regression_loss: 1.4024 - val_probability_accuracy: 0.8692
# Epoch 5/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.9400 - probability_loss: 0.4782 - bbox_regression_loss: 1.4521 - probability_accuracy: 0.7944 - val_loss: 1.7248 - val_probability_loss: 0.3840 - val_bbox_regression_loss: 1.3311 - val_probability_accuracy: 0.8790
# Epoch 6/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.8202 - probability_loss: 0.4571 - bbox_regression_loss: 1.3534 - probability_accuracy: 0.7954 - val_loss: 1.5943 - val_probability_loss: 0.3524 - val_bbox_regression_loss: 1.2322 - val_probability_accuracy: 0.8893
# Epoch 7/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.7046 - probability_loss: 0.4327 - bbox_regression_loss: 1.2623 - probability_accuracy: 0.8110 - val_loss: 1.4829 - val_probability_loss: 0.3239 - val_bbox_regression_loss: 1.1493 - val_probability_accuracy: 0.8964
# Epoch 8/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.6270 - probability_loss: 0.4207 - bbox_regression_loss: 1.1966 - probability_accuracy: 0.8053 - val_loss: 1.3965 - val_probability_loss: 0.2987 - val_bbox_regression_loss: 1.0880 - val_probability_accuracy: 0.9022
# Epoch 9/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.5520 - probability_loss: 0.3983 - bbox_regression_loss: 1.1440 - probability_accuracy: 0.8225 - val_loss: 1.3384 - val_probability_loss: 0.2796 - val_bbox_regression_loss: 1.0490 - val_probability_accuracy: 0.9018
# Epoch 10/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.5086 - probability_loss: 0.3848 - bbox_regression_loss: 1.1141 - probability_accuracy: 0.8351 - val_loss: 1.2918 - val_probability_loss: 0.2632 - val_bbox_regression_loss: 1.0188 - val_probability_accuracy: 0.9049
# Epoch 11/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.4557 - probability_loss: 0.3626 - bbox_regression_loss: 1.0833 - probability_accuracy: 0.8406 - val_loss: 1.2612 - val_probability_loss: 0.2514 - val_bbox_regression_loss: 1.0000 - val_probability_accuracy: 0.9067
# Epoch 12/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.4241 - probability_loss: 0.3487 - bbox_regression_loss: 1.0657 - probability_accuracy: 0.8456 - val_loss: 1.2369 - val_probability_loss: 0.2412 - val_bbox_regression_loss: 0.9859 - val_probability_accuracy: 0.9094
# Epoch 13/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.3962 - probability_loss: 0.3333 - bbox_regression_loss: 1.0531 - probability_accuracy: 0.8573 - val_loss: 1.2205 - val_probability_loss: 0.2332 - val_bbox_regression_loss: 0.9775 - val_probability_accuracy: 0.9094
# Epoch 14/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.3715 - probability_loss: 0.3244 - bbox_regression_loss: 1.0373 - probability_accuracy: 0.8630 - val_loss: 1.2057 - val_probability_loss: 0.2274 - val_bbox_regression_loss: 0.9685 - val_probability_accuracy: 0.9089
# Epoch 15/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.3402 - probability_loss: 0.3063 - bbox_regression_loss: 1.0241 - probability_accuracy: 0.8691 - val_loss: 1.1935 - val_probability_loss: 0.2198 - val_bbox_regression_loss: 0.9638 - val_probability_accuracy: 0.9143
# Epoch 16/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.3192 - probability_loss: 0.2913 - bbox_regression_loss: 1.0181 - probability_accuracy: 0.8802 - val_loss: 1.1838 - val_probability_loss: 0.2143 - val_bbox_regression_loss: 0.9596 - val_probability_accuracy: 0.9165
# Epoch 17/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.3162 - probability_loss: 0.2900 - bbox_regression_loss: 1.0163 - probability_accuracy: 0.8810 - val_loss: 1.1754 - val_probability_loss: 0.2111 - val_bbox_regression_loss: 0.9545 - val_probability_accuracy: 0.9201
# Epoch 18/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.3196 - probability_loss: 0.3018 - bbox_regression_loss: 1.0079 - probability_accuracy: 0.8782 - val_loss: 1.1695 - val_probability_loss: 0.2083 - val_bbox_regression_loss: 0.9513 - val_probability_accuracy: 0.9192
# Epoch 19/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2964 - probability_loss: 0.2917 - bbox_regression_loss: 0.9949 - probability_accuracy: 0.8782 - val_loss: 1.1635 - val_probability_loss: 0.2041 - val_bbox_regression_loss: 0.9496 - val_probability_accuracy: 0.9223
# Epoch 20/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2872 - probability_loss: 0.2783 - bbox_regression_loss: 0.9991 - probability_accuracy: 0.8855 - val_loss: 1.1591 - val_probability_loss: 0.2020 - val_bbox_regression_loss: 0.9472 - val_probability_accuracy: 0.9219
# Epoch 21/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.2605 - probability_loss: 0.2623 - bbox_regression_loss: 0.9884 - probability_accuracy: 0.8980 - val_loss: 1.1543 - val_probability_loss: 0.1988 - val_bbox_regression_loss: 0.9456 - val_probability_accuracy: 0.9228
# Epoch 22/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.2570 - probability_loss: 0.2592 - bbox_regression_loss: 0.9880 - probability_accuracy: 0.8967 - val_loss: 1.1501 - val_probability_loss: 0.1959 - val_bbox_regression_loss: 0.9443 - val_probability_accuracy: 0.9223
# Epoch 23/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2756 - probability_loss: 0.2822 - bbox_regression_loss: 0.9834 - probability_accuracy: 0.8835 - val_loss: 1.1470 - val_probability_loss: 0.1942 - val_bbox_regression_loss: 0.9430 - val_probability_accuracy: 0.9246
# Epoch 24/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.2430 - probability_loss: 0.2564 - bbox_regression_loss: 0.9768 - probability_accuracy: 0.8962 - val_loss: 1.1433 - val_probability_loss: 0.1921 - val_bbox_regression_loss: 0.9413 - val_probability_accuracy: 0.9241
# Epoch 25/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2369 - probability_loss: 0.2505 - bbox_regression_loss: 0.9765 - probability_accuracy: 0.9001 - val_loss: 1.1412 - val_probability_loss: 0.1915 - val_bbox_regression_loss: 0.9398 - val_probability_accuracy: 0.9268
# Epoch 26/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.2429 - probability_loss: 0.2600 - bbox_regression_loss: 0.9731 - probability_accuracy: 0.8948 - val_loss: 1.1371 - val_probability_loss: 0.1885 - val_bbox_regression_loss: 0.9387 - val_probability_accuracy: 0.9259
# Epoch 27/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2317 - probability_loss: 0.2574 - bbox_regression_loss: 0.9644 - probability_accuracy: 0.8947 - val_loss: 1.1343 - val_probability_loss: 0.1854 - val_bbox_regression_loss: 0.9391 - val_probability_accuracy: 0.9250
# Epoch 28/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2276 - probability_loss: 0.2476 - bbox_regression_loss: 0.9700 - probability_accuracy: 0.9048 - val_loss: 1.1321 - val_probability_loss: 0.1853 - val_bbox_regression_loss: 0.9369 - val_probability_accuracy: 0.9281
# Epoch 29/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2171 - probability_loss: 0.2384 - bbox_regression_loss: 0.9687 - probability_accuracy: 0.9018 - val_loss: 1.1288 - val_probability_loss: 0.1831 - val_bbox_regression_loss: 0.9358 - val_probability_accuracy: 0.9286
# Epoch 30/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.2191 - probability_loss: 0.2462 - bbox_regression_loss: 0.9629 - probability_accuracy: 0.9037 - val_loss: 1.1255 - val_probability_loss: 0.1802 - val_bbox_regression_loss: 0.9354 - val_probability_accuracy: 0.9290
# Epoch 31/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.2101 - probability_loss: 0.2332 - bbox_regression_loss: 0.9670 - probability_accuracy: 0.9065 - val_loss: 1.1234 - val_probability_loss: 0.1791 - val_bbox_regression_loss: 0.9344 - val_probability_accuracy: 0.9295
# Epoch 32/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.
100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0972 - probability_loss: 0.1702 - bbox_regression_loss: 0.9169 - probability_accuracy: 0.9346 - val_loss: 1.0402 - val_probability_loss: 0.1339 - val_bbox_regression_loss: 0.8962 - val_probability_accuracy: 0.9500
# Epoch 85/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0979 - probability_loss: 0.1747 - bbox_regression_loss: 0.9130 - probability_accuracy: 0.9348 - val_loss: 1.0396 - val_probability_loss: 0.1339 - val_bbox_regression_loss: 0.8956 - val_probability_accuracy: 0.9504
# Epoch 86/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0880 - probability_loss: 0.1672 - bbox_regression_loss: 0.9107 - probability_accuracy: 0.9339 - val_loss: 1.0377 - val_probability_loss: 0.1328 - val_bbox_regression_loss: 0.8948 - val_probability_accuracy: 0.9496
# Epoch 87/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0926 - probability_loss: 0.1651 - bbox_regression_loss: 0.9174 - probability_accuracy: 0.9347 - val_loss: 1.0384 - val_probability_loss: 0.1338 - val_bbox_regression_loss: 0.8945 - val_probability_accuracy: 0.9509
# Epoch 88/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0921 - probability_loss: 0.1684 - bbox_regression_loss: 0.9136 - probability_accuracy: 0.9325 - val_loss: 1.0370 - val_probability_loss: 0.1317 - val_bbox_regression_loss: 0.8951 - val_probability_accuracy: 0.9504
# Epoch 89/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.1041 - probability_loss: 0.1798 - bbox_regression_loss: 0.9142 - probability_accuracy: 0.9305 - val_loss: 1.0336 - val_probability_loss: 0.1297 - val_bbox_regression_loss: 0.8938 - val_probability_accuracy: 0.9504
# Epoch 90/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0894 - probability_loss: 0.1695 - bbox_regression_loss: 0.9097 - probability_accuracy: 0.9423 - val_loss: 1.0339 - val_probability_loss: 0.1299 - val_bbox_regression_loss: 0.8939 - val_probability_accuracy: 0.9504
# Epoch 91/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0934 - probability_loss: 0.1667 - bbox_regression_loss: 0.9165 - probability_accuracy: 0.9366 - val_loss: 1.0315 - val_probability_loss: 0.1280 - val_bbox_regression_loss: 0.8933 - val_probability_accuracy: 0.9509
# Epoch 92/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0786 - probability_loss: 0.1601 - bbox_regression_loss: 0.9084 - probability_accuracy: 0.9392 - val_loss: 1.0309 - val_probability_loss: 0.1274 - val_bbox_regression_loss: 0.8934 - val_probability_accuracy: 0.9509
# Epoch 93/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0798 - probability_loss: 0.1581 - bbox_regression_loss: 0.9116 - probability_accuracy: 0.9403 - val_loss: 1.0320 - val_probability_loss: 0.1283 - val_bbox_regression_loss: 0.8936 - val_probability_accuracy: 0.9513
# Epoch 94/100
# 560/560 [==============================] - 7s 13ms/step - loss: 1.0887 - probability_loss: 0.1688 - bbox_regression_loss: 0.9097 - probability_accuracy: 0.9363 - val_loss: 1.0293 - val_probability_loss: 0.1272 - val_bbox_regression_loss: 0.8919 - val_probability_accuracy: 0.9527
# Epoch 95/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.0934 - probability_loss: 0.1702 - bbox_regression_loss: 0.9130 - probability_accuracy: 0.9350 - val_loss: 1.0292 - val_probability_loss: 0.1266 - val_bbox_regression_loss: 0.8924 - val_probability_accuracy: 0.9522
# Epoch 96/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.0849 - probability_loss: 0.1673 - bbox_regression_loss: 0.9075 - probability_accuracy: 0.9391 - val_loss: 1.0262 - val_probability_loss: 0.1244 - val_bbox_regression_loss: 0.8917 - val_probability_accuracy: 0.9531
# Epoch 97/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.0789 - probability_loss: 0.1621 - bbox_regression_loss: 0.9066 - probability_accuracy: 0.9383 - val_loss: 1.0264 - val_probability_loss: 0.1245 - val_bbox_regression_loss: 0.8917 - val_probability_accuracy: 0.9522
# Epoch 98/100
# 560/560 [==============================] - 8s 13ms/step - loss: 1.0805 - probability_loss: 0.1617 - bbox_regression_loss: 0.9086 - probability_accuracy: 0.9374 - val_loss: 1.0237 - val_probability_loss: 0.1230 - val_bbox_regression_loss: 0.8906 - val_probability_accuracy: 0.9527
# Epoch 99/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0659 - probability_loss: 0.1477 - bbox_regression_loss: 0.9080 - probability_accuracy: 0.9449 - val_loss: 1.0226 - val_probability_loss: 0.1209 - val_bbox_regression_loss: 0.8916 - val_probability_accuracy: 0.9536
# Epoch 100/100
# 560/560 [==============================] - 8s 14ms/step - loss: 1.0679 - probability_loss: 0.1505 - bbox_regression_loss: 0.9072 - probability_accuracy: 0.9407 - val_loss: 1.0220 - val_probability_loss: 0.1212 - val_bbox_regression_loss: 0.8906 - val_probability_accuracy: 0.9549
# [INFO] Training halted, plotting training history ...

# %% [markdown]
# # Training O-Net

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(input_dim*4,input_dim*4))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(10, 30), frame_per_img=4, img_size=input_dim*4)
pos_samples[:, 2] = 1.0

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() 
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

onet = build_pnet_model(input_shape=input_dim*4, batch_norm=True, dropout=True, n_classes=n_classes)
print(onet.summary())

if(os.path.exists(onet_weights)):
    print('[INFO] Loading O-Net pretrained weights ...')
    onet.load_weights(onet_weights)
onet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})

history = onet.fit(train_images, y, epochs=epochs, validation_split=0.2, batch_size=batch_size, callbacks=onet_callbacks)
print('[INFO] Training halted, plotting training history ... ')

history = history.history
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
ax[0].plot(history['probability_loss'], color='orange', label='Training')
ax[0].plot(history['val_probability_loss'], color='blue', label='Validation')
""
ax[1].plot(history['bbox_regression_loss'], color='orange', label='Training')
ax[1].plot(history['val_bbox_regression_loss'], color='blue', label='Validation')

ax[0].legend()
ax[0].set_title('Classification losses')

ax[1].legend()
ax[1].set_title('BBox regression losses')

plt.savefig('ONet_training_result.png')
plt.show()
# Out:
# [INFO] From images to ground truth ...
# [INFO] Converting to raw dataset ...
# [INFO] 1244 samples loaded ...
# [INFO] 4976 negative samples generated ...
# <ipython-input-3-223f64bb23c3>:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(neg_samples)
# <ipython-input-4-280b28c2d059>:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(pos_samples)
# [INFO] 4976 positive samples generated ...
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# model_7 (Functional)            (None, None, None, 1 330         input_12[0][0]
# __________________________________________________________________________________________________
# model_8 (Functional)            (None, None, None, 1 960         model_7[0][0]
# __________________________________________________________________________________________________
# model_9 (Functional)            (None, None, None, 1 960         model_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 1456        model_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, None, None, 1 16          conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 3 4640        p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, None, None, 3 32          conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, None, None, 3 0           p_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 66          dropout_4[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout_4[0][0]
# ==================================================================================================
# Total params: 8,592
# Trainable params: 8,532
# Non-trainable params: 60
# __________________________________________________________________________________________________
# None
# Epoch 1/100
#
100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.3462 - probability_loss: 0.3710 - bbox_regression_loss: 0.9636 - probability_accuracy: 0.8341 - val_loss: 1.2118 - val_probability_loss: 0.2951 - val_bbox_regression_loss: 0.9050 - val_probability_accuracy: 0.8689
# Epoch 27/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.3457 - probability_loss: 0.3715 - bbox_regression_loss: 0.9625 - probability_accuracy: 0.8349 - val_loss: 1.2096 - val_probability_loss: 0.2934 - val_bbox_regression_loss: 0.9045 - val_probability_accuracy: 0.8699
# Epoch 28/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3415 - probability_loss: 0.3659 - bbox_regression_loss: 0.9639 - probability_accuracy: 0.8403 - val_loss: 1.2055 - val_probability_loss: 0.2913 - val_bbox_regression_loss: 0.9026 - val_probability_accuracy: 0.8744
# Epoch 29/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3449 - probability_loss: 0.3769 - bbox_regression_loss: 0.9564 - probability_accuracy: 0.8244 - val_loss: 1.2045 - val_probability_loss: 0.2897 - val_bbox_regression_loss: 0.9032 - val_probability_accuracy: 0.8724
# Epoch 30/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3236 - probability_loss: 0.3589 - bbox_regression_loss: 0.9531 - probability_accuracy: 0.8429 - val_loss: 1.2025 - val_probability_loss: 0.2886 - val_bbox_regression_loss: 0.9023 - val_probability_accuracy: 0.8764
# Epoch 31/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.3378 - probability_loss: 0.3709 - bbox_regression_loss: 0.9552 - probability_accuracy: 0.8334 - val_loss: 1.2014 - val_probability_loss: 0.2866 - val_bbox_regression_loss: 0.9031 - val_probability_accuracy: 0.8729
# Epoch 32/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3259 - probability_loss: 0.3595 - bbox_regression_loss: 0.9547 - probability_accuracy: 0.8436 - val_loss: 1.1995 - val_probability_loss: 0.2853 - val_bbox_regression_loss: 0.9025 - val_probability_accuracy: 0.8724
# Epoch 33/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3305 - probability_loss: 0.3625 - bbox_regression_loss: 0.9564 - probability_accuracy: 0.8374 - val_loss: 1.1970 - val_probability_loss: 0.2834 - val_bbox_regression_loss: 0.9019 - val_probability_accuracy: 0.8774
# Epoch 34/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3099 - probability_loss: 0.3526 - bbox_regression_loss: 0.9456 - probability_accuracy: 0.8494 - val_loss: 1.1956 - val_probability_loss: 0.2823 - val_bbox_regression_loss: 0.9017 - val_probability_accuracy: 0.8769
# Epoch 35/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.3152 - probability_loss: 0.3528 - bbox_regression_loss: 0.9507 - probability_accuracy: 0.8445 - val_loss: 1.1941 - val_probability_loss: 0.2805 - val_bbox_regression_loss: 0.9019 - val_probability_accuracy: 0.8774
# Epoch 36/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3151 - probability_loss: 0.3528 - bbox_regression_loss: 0.9506 - probability_accuracy: 0.8431 - val_loss: 1.1922 - val_probability_loss: 0.2800 - val_bbox_regression_loss: 0.9005 - val_probability_accuracy: 0.8754
# Epoch 37/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3209 - probability_loss: 0.3556 - bbox_regression_loss: 0.9536 - probability_accuracy: 0.8375 - val_loss: 1.1907 - val_probability_loss: 0.2785 - val_bbox_regression_loss: 0.9006 - val_probability_accuracy: 0.8769
# Epoch 38/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.3145 - probability_loss: 0.3550 - bbox_regression_loss: 0.9478 - probability_accuracy: 0.8447 - val_loss: 1.1906 - val_probability_loss: 0.2773 - val_bbox_regression_loss: 0.9017 - val_probability_accuracy: 0.8764
# Epoch 39/100
# 498/498 [==============================] - 8s 15ms/step - loss: 1.2968 - probability_loss: 0.3389 - bbox_regression_loss: 0.9462 - probability_accuracy: 0.8518 - val_loss: 1.1871 - val_probability_loss: 0.2753 - val_bbox_regression_loss: 0.9001 - val_probability_accuracy: 0.8800
# Epoch 40/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2909 - probability_loss: 0.3302 - bbox_regression_loss: 0.9490 - probability_accuracy: 0.8606 - val_loss: 1.1859 - val_probability_loss: 0.2741 - val_bbox_regression_loss: 0.9001 - val_probability_accuracy: 0.8795
# Epoch 41/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2896 - probability_loss: 0.3317 - bbox_regression_loss: 0.9462 - probability_accuracy: 0.8557 - val_loss: 1.1844 - val_probability_loss: 0.2725 - val_bbox_regression_loss: 0.9003 - val_probability_accuracy: 0.8810
# Epoch 42/100
# 498/498 [==============================] - 7s 13ms/step - loss: 1.3036 - probability_loss: 0.3440 - bbox_regression_loss: 0.9478 - probability_accuracy: 0.8492 - val_loss: 1.1829 - val_probability_loss: 0.2713 - val_bbox_regression_loss: 0.8999 - val_probability_accuracy: 0.8805
# Epoch 43/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2812 - probability_loss: 0.3256 - bbox_regression_loss: 0.9440 - probability_accuracy: 0.8601 - val_loss: 1.1803 - val_probability_loss: 0.2698 - val_bbox_regression_loss: 0.8989 - val_probability_accuracy: 0.8810
# Epoch 44/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2876 - probability_loss: 0.3315 - bbox_regression_loss: 0.9444 - probability_accuracy: 0.8547 - val_loss: 1.1793 - val_probability_loss: 0.2684 - val_bbox_regression_loss: 0.8992 - val_probability_accuracy: 0.8805
# Epoch 45/100
# 498/498 [==============================] - 7s 13ms/step - loss: 1.2999 - probability_loss: 0.3391 - bbox_regression_loss: 0.9492 - probability_accuracy: 0.8513 - val_loss: 1.1780 - val_probability_loss: 0.2675 - val_bbox_regression_loss: 0.8989 - val_probability_accuracy: 0.8820
# Epoch 46/100
# 498/498 [==============================] - 7s 13ms/step - loss: 1.2878 - probability_loss: 0.3318 - bbox_regression_loss: 0.9443 - probability_accuracy: 0.8615 - val_loss: 1.1764 - val_probability_loss: 0.2659 - val_bbox_regression_loss: 0.8988 - val_probability_accuracy: 0.8815
# Epoch 47/100
# 498/498 [==============================] - 7s 13ms/step - loss: 1.2790 - probability_loss: 0.3252 - bbox_regression_loss: 0.9421 - probability_accuracy: 0.8608 - val_loss: 1.1759 - val_probability_loss: 0.2648 - val_bbox_regression_loss: 0.8994 - val_probability_accuracy: 0.8825
# Epoch 48/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2842 - probability_loss: 0.3310 - bbox_regression_loss: 0.9415 - probability_accuracy: 0.8525 - val_loss: 1.1740 - val_probability_loss: 0.2636 - val_bbox_regression_loss: 0.8987 - val_probability_accuracy: 0.8830
# Epoch 49/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2851 - probability_loss: 0.3348 - bbox_regression_loss: 0.9386 - probability_accuracy: 0.8583 - val_loss: 1.1723 - val_probability_loss: 0.2622 - val_bbox_regression_loss: 0.8983 - val_probability_accuracy: 0.8830
# Epoch 50/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2702 - probability_loss: 0.3159 - bbox_regression_loss: 0.9427 - probability_accuracy: 0.8645 - val_loss: 1.1701 - val_probability_loss: 0.2604 - val_bbox_regression_loss: 0.8980 - val_probability_accuracy: 0.8840
# Epoch 51/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2881 - probability_loss: 0.3369 - bbox_regression_loss: 0.9395 - probability_accuracy: 0.8526 - val_loss: 1.1679 - val_probability_loss: 0.2591 - val_bbox_regression_loss: 0.8971 - val_probability_accuracy: 0.8855
# Epoch 52/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2926 - probability_loss: 0.3370 - bbox_regression_loss: 0.9439 - probability_accuracy: 0.8537 - val_loss: 1.1658 - val_probability_loss: 0.2578 - val_bbox_regression_loss: 0.8964 - val_probability_accuracy: 0.8850
# Epoch 53/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2589 - probability_loss: 0.3082 - bbox_regression_loss: 0.9391 - probability_accuracy: 0.8651 - val_loss: 1.1652 - val_probability_loss: 0.2565 - val_bbox_regression_loss: 0.8970 - val_probability_accuracy: 0.8855
# Epoch 54/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2733 - probability_loss: 0.3232 - bbox_regression_loss: 0.9384 - probability_accuracy: 0.8551 - val_loss: 1.1638 - val_probability_loss: 0.2549 - val_bbox_regression_loss: 0.8972 - val_probability_accuracy: 0.8875
# Epoch 55/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2627 - probability_loss: 0.3153 - bbox_regression_loss: 0.9357 - probability_accuracy: 0.8622 - val_loss: 1.1612 - val_probability_loss: 0.2530 - val_bbox_regression_loss: 0.8965 - val_probability_accuracy: 0.8910
# Epoch 56/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2609 - probability_loss: 0.3091 - bbox_regression_loss: 0.9401 - probability_accuracy: 0.8649 - val_loss: 1.1602 - val_probability_loss: 0.2518 - val_bbox_regression_loss: 0.8967 - val_probability_accuracy: 0.8915
# Epoch 57/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2627 - probability_loss: 0.3184 - bbox_regression_loss: 0.9326 - probability_accuracy: 0.8636 - val_loss: 1.1583 - val_probability_loss: 0.2505 - val_bbox_regression_loss: 0.8961 - val_probability_accuracy: 0.8950
# Epoch 58/100
# 498/498 [==============================] - 7s 13ms/step - loss: 1.2481 - probability_loss: 0.3015 - bbox_regression_loss: 0.9349 - probability_accuracy: 0.8704 - val_loss: 1.1574 - val_probability_loss: 0.2500 - val_bbox_regression_loss: 0.8958 - val_probability_accuracy: 0.8955
# Epoch 59/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2528 - probability_loss: 0.3098 - bbox_regression_loss: 0.9313 - probability_accuracy: 0.8675 - val_loss: 1.1560 - val_probability_loss: 0.2483 - val_bbox_regression_loss: 0.8961 - val_probability_accuracy: 0.8945
# Epoch 60/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2479 - probability_loss: 0.3056 - bbox_regression_loss: 0.9306 - probability_accuracy: 0.8707 - val_loss: 1.1544 - val_probability_loss: 0.2467 - val_bbox_regression_loss: 0.8960 - val_probability_accuracy: 0.8960
# Epoch 61/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2542 - probability_loss: 0.3056 - bbox_regression_loss: 0.9369 - probability_accuracy: 0.8719 - val_loss: 1.1524 - val_probability_loss: 0.2453 - val_bbox_regression_loss: 0.8955 - val_probability_accuracy: 0.8980
# Epoch 62/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2605 - probability_loss: 0.3182 - bbox_regression_loss: 0.9306 - probability_accuracy: 0.8589 - val_loss: 1.1510 - val_probability_loss: 0.2442 - val_bbox_regression_loss: 0.8951 - val_probability_accuracy: 0.8990
# Epoch 63/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2369 - probability_loss: 0.2936 - bbox_regression_loss: 0.9316 - probability_accuracy: 0.8769 - val_loss: 1.1494 - val_probability_loss: 0.2431 - val_bbox_regression_loss: 0.8946 - val_probability_accuracy: 0.8985
# Epoch 64/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2281 - probability_loss: 0.2868 - bbox_regression_loss: 0.9296 - probability_accuracy: 0.8813 - val_loss: 1.1480 - val_probability_loss: 0.2415 - val_bbox_regression_loss: 0.8948 - val_probability_accuracy: 0.9001
# Epoch 65/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2278 - probability_loss: 0.2866 - bbox_regression_loss: 0.9295 - probability_accuracy: 0.8756 - val_loss: 1.1461 - val_probability_loss: 0.2395 - val_bbox_regression_loss: 0.8948 - val_probability_accuracy: 0.9001
# Epoch 66/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2314 - probability_loss: 0.2905 - bbox_regression_loss: 0.9291 - probability_accuracy: 0.8797 - val_loss: 1.1453 - val_probability_loss: 0.2389 - val_bbox_regression_loss: 0.8946 - val_probability_accuracy: 0.9006
# Epoch 67/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2307 - probability_loss: 0.2919 - bbox_regression_loss: 0.9271 - probability_accuracy: 0.8673 - val_loss: 1.1439 - val_probability_loss: 0.2380 - val_bbox_regression_loss: 0.8941 - val_probability_accuracy: 0.9021
# Epoch 68/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2286 - probability_loss: 0.2883 - bbox_regression_loss: 0.9286 - probability_accuracy: 0.8761 - val_loss: 1.1422 - val_probability_loss: 0.2361 - val_bbox_regression_loss: 0.8943 - val_probability_accuracy: 0.9031
# Epoch 69/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2312 - probability_loss: 0.2911 - bbox_regression_loss: 0.9284 - probability_accuracy: 0.8727 - val_loss: 1.1409 - val_probability_loss: 0.2345 - val_bbox_regression_loss: 0.8947 - val_probability_accuracy: 0.9021
# Epoch 70/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2181 - probability_loss: 0.2764 - bbox_regression_loss: 0.9300 - probability_accuracy: 0.8809 - val_loss: 1.1381 - val_probability_loss: 0.2332 - val_bbox_regression_loss: 0.8932 - val_probability_accuracy: 0.9046
# Epoch 71/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2138 - probability_loss: 0.2741 - bbox_regression_loss: 0.9279 - probability_accuracy: 0.8876 - val_loss: 1.1366 - val_probability_loss: 0.2321 - val_bbox_regression_loss: 0.8927 - val_probability_accuracy: 0.9036
# Epoch 72/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2220 - probability_loss: 0.2832 - bbox_regression_loss: 0.9271 - probability_accuracy: 0.8750 - val_loss: 1.1351 - val_probability_loss: 0.2311 - val_bbox_regression_loss: 0.8922 - val_probability_accuracy: 0.9051
# Epoch 73/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2105 - probability_loss: 0.2734 - bbox_regression_loss: 0.9254 - probability_accuracy: 0.8859 - val_loss: 1.1337 - val_probability_loss: 0.2301 - val_bbox_regression_loss: 0.8919 - val_probability_accuracy: 0.9056
# Epoch 74/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2122 - probability_loss: 0.2743 - bbox_regression_loss: 0.9262 - probability_accuracy: 0.8806 - val_loss: 1.1321 - val_probability_loss: 0.2284 - val_bbox_regression_loss: 0.8919 - val_probability_accuracy: 0.9046
# Epoch 75/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2126 - probability_loss: 0.2756 - bbox_regression_loss: 0.9252 - probability_accuracy: 0.8800 - val_loss: 1.1315 - val_probability_loss: 0.2275 - val_bbox_regression_loss: 0.8923 - val_probability_accuracy: 0.9071
# Epoch 76/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2197 - probability_loss: 0.2811 - bbox_regression_loss: 0.9268 - probability_accuracy: 0.8830 - val_loss: 1.1294 - val_probability_loss: 0.2261 - val_bbox_regression_loss: 0.8916 - val_probability_accuracy: 0.9091
# Epoch 77/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2058 - probability_loss: 0.2695 - bbox_regression_loss: 0.9245 - probability_accuracy: 0.8893 - val_loss: 1.1284 - val_probability_loss: 0.2255 - val_bbox_regression_loss: 0.8911 - val_probability_accuracy: 0.9106
# Epoch 78/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2129 - probability_loss: 0.2744 - bbox_regression_loss: 0.9267 - probability_accuracy: 0.8809 - val_loss: 1.1257 - val_probability_loss: 0.2235 - val_bbox_regression_loss: 0.8904 - val_probability_accuracy: 0.9106
# Epoch 79/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2111 - probability_loss: 0.2720 - bbox_regression_loss: 0.9274 - probability_accuracy: 0.8873 - val_loss: 1.1243 - val_probability_loss: 0.2230 - val_bbox_regression_loss: 0.8896 - val_probability_accuracy: 0.9126
# Epoch 80/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2228 - probability_loss: 0.2867 - bbox_regression_loss: 0.9243 - probability_accuracy: 0.8787 - val_loss: 1.1234 - val_probability_loss: 0.2216 - val_bbox_regression_loss: 0.8900 - val_probability_accuracy: 0.9111
# Epoch 81/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1983 - probability_loss: 0.2657 - bbox_regression_loss: 0.9208 - probability_accuracy: 0.8925 - val_loss: 1.1218 - val_probability_loss: 0.2208 - val_bbox_regression_loss: 0.8893 - val_probability_accuracy: 0.9126
# Epoch 82/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2092 - probability_loss: 0.2743 - bbox_regression_loss: 0.9231 - probability_accuracy: 0.8834 - val_loss: 1.1206 - val_probability_loss: 0.2193 - val_bbox_regression_loss: 0.8896 - val_probability_accuracy: 0.9141
# Epoch 83/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1959 - probability_loss: 0.2598 - bbox_regression_loss: 0.9243 - probability_accuracy: 0.8946 - val_loss: 1.1198 - val_probability_loss: 0.2186 - val_bbox_regression_loss: 0.8895 - val_probability_accuracy: 0.9116
# Epoch 84/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.2155 - probability_loss: 0.2761 - bbox_regression_loss: 0.9277 - probability_accuracy: 0.8891 - val_loss: 1.1186 - val_probability_loss: 0.2168 - val_bbox_regression_loss: 0.8900 - val_probability_accuracy: 0.9141
# Epoch 85/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.2015 - probability_loss: 0.2666 - bbox_regression_loss: 0.9232 - probability_accuracy: 0.8872 - val_loss: 1.1183 - val_probability_loss: 0.2162 - val_bbox_regression_loss: 0.8903 - val_probability_accuracy: 0.9146
# Epoch 86/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1871 - probability_loss: 0.2533 - bbox_regression_loss: 0.9221 - probability_accuracy: 0.8953 - val_loss: 1.1170 - val_probability_loss: 0.2152 - val_bbox_regression_loss: 0.8900 - val_probability_accuracy: 0.9126
# Epoch 87/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1871 - probability_loss: 0.2544 - bbox_regression_loss: 0.9210 - probability_accuracy: 0.8873 - val_loss: 1.1148 - val_probability_loss: 0.2136 - val_bbox_regression_loss: 0.8895 - val_probability_accuracy: 0.9156
# Epoch 88/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1707 - probability_loss: 0.2396 - bbox_regression_loss: 0.9194 - probability_accuracy: 0.8959 - val_loss: 1.1129 - val_probability_loss: 0.2125 - val_bbox_regression_loss: 0.8886 - val_probability_accuracy: 0.9161
# Epoch 89/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1776 - probability_loss: 0.2452 - bbox_regression_loss: 0.9206 - probability_accuracy: 0.9002 - val_loss: 1.1115 - val_probability_loss: 0.2108 - val_bbox_regression_loss: 0.8890 - val_probability_accuracy: 0.9156
# Epoch 90/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1919 - probability_loss: 0.2617 - bbox_regression_loss: 0.9184 - probability_accuracy: 0.8968 - val_loss: 1.1093 - val_probability_loss: 0.2094 - val_bbox_regression_loss: 0.8880 - val_probability_accuracy: 0.9176
# Epoch 91/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1912 - probability_loss: 0.2547 - bbox_regression_loss: 0.9247 - probability_accuracy: 0.8934 - val_loss: 1.1089 - val_probability_loss: 0.2084 - val_bbox_regression_loss: 0.8888 - val_probability_accuracy: 0.9186
# Epoch 92/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1923 - probability_loss: 0.2612 - bbox_regression_loss: 0.9194 - probability_accuracy: 0.8935 - val_loss: 1.1076 - val_probability_loss: 0.2075 - val_bbox_regression_loss: 0.8883 - val_probability_accuracy: 0.9181
# Epoch 93/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1869 - probability_loss: 0.2575 - bbox_regression_loss: 0.9176 - probability_accuracy: 0.8897 - val_loss: 1.1060 - val_probability_loss: 0.2059 - val_bbox_regression_loss: 0.8884 - val_probability_accuracy: 0.9201
# Epoch 94/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1823 - probability_loss: 0.2493 - bbox_regression_loss: 0.9212 - probability_accuracy: 0.8957 - val_loss: 1.1043 - val_probability_loss: 0.2050 - val_bbox_regression_loss: 0.8875 - val_probability_accuracy: 0.9186
# Epoch 95/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1803 - probability_loss: 0.2467 - bbox_regression_loss: 0.9218 - probability_accuracy: 0.8950 - val_loss: 1.1028 - val_probability_loss: 0.2040 - val_bbox_regression_loss: 0.8870 - val_probability_accuracy: 0.9216
# Epoch 96/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1711 - probability_loss: 0.2408 - bbox_regression_loss: 0.9185 - probability_accuracy: 0.9038 - val_loss: 1.1017 - val_probability_loss: 0.2027 - val_bbox_regression_loss: 0.8872 - val_probability_accuracy: 0.9206
# Epoch 97/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1618 - probability_loss: 0.2308 - bbox_regression_loss: 0.9192 - probability_accuracy: 0.9023 - val_loss: 1.1010 - val_probability_loss: 0.2018 - val_bbox_regression_loss: 0.8874 - val_probability_accuracy: 0.9186
# Epoch 98/100
# 498/498 [==============================] - 7s 15ms/step - loss: 1.1804 - probability_loss: 0.2496 - bbox_regression_loss: 0.9190 - probability_accuracy: 0.8963 - val_loss: 1.1005 - val_probability_loss: 0.2018 - val_bbox_regression_loss: 0.8869 - val_probability_accuracy: 0.9201
# Epoch 99/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1701 - probability_loss: 0.2421 - bbox_regression_loss: 0.9162 - probability_accuracy: 0.9024 - val_loss: 1.0987 - val_probability_loss: 0.2003 - val_bbox_regression_loss: 0.8866 - val_probability_accuracy: 0.9201
# Epoch 100/100
# 498/498 [==============================] - 7s 14ms/step - loss: 1.1608 - probability_loss: 0.2341 - bbox_regression_loss: 0.9148 - probability_accuracy: 0.9036 - val_loss: 1.0971 - val_probability_loss: 0.1992 - val_bbox_regression_loss: 0.8861 - val_probability_accuracy: 0.9221
# [INFO] Training halted, plotting training history ...

# %% [markdown]
# # Test P-Net proposals

# %%
pnet = build_pnet_model(input_shape=input_dim, batch_norm=True, dropout=True, n_classes=n_classes)
rnet = build_pnet_model(input_shape=input_dim*2, batch_norm=True, dropout=True, n_classes=n_classes)
onet = build_pnet_model(input_shape=input_dim*4, batch_norm=True, dropout=True, n_classes=n_classes)


if(os.path.exists(pnet_weights)):
    print('[INFO] Loading weights for P-Net ... ')
    pnet.load_weights(pnet_weights)

if(os.path.exists(rnet_weights)):
    print('[INFO] Loading weights for R-Net ... ')
    rnet.load_weights(rnet_weights)

if(os.path.exists(onet_weights)):
    print('[INFO] Loading weights for o-Net ... ')
    onet.load_weights(onet_weights)
    
def __nms(boxes, s, threshold, method):
    """
        Non Maximum Suppression.

        Params:
            @param boxes: np array with bounding boxes.
            @param threshold:
            @param method: NMS method to apply. Available values ('Min', 'Union')
        
        Return:
            pick : An array of indices selected.
    """
    if boxes.size == 0:
        return np.empty((0, 3))

    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2] + x1
    y2 = boxes[:, 3] + y1

    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    sorted_s = np.argsort(s)

    pick = np.zeros_like(s, dtype=np.int16)
    counter = 0
    while sorted_s.size > 0:
        i = sorted_s[-1]
        pick[counter] = i
        counter += 1
        idx = sorted_s[0:-1]

        xx1 = np.maximum(x1[i], x1[idx])
        yy1 = np.maximum(y1[i], y1[idx])
        xx2 = np.minimum(x2[i], x2[idx])
        yy2 = np.minimum(y2[i], y2[idx])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)

        inter = w * h

        if method == 'Min':
            o = inter / np.minimum(area[i], area[idx])
        else:
            o = inter / (area[i] + area[idx] - inter)

        sorted_s = sorted_s[np.where(o <= threshold)]

    pick = pick[0:counter]

    return pick
# Out:
# [INFO] Loading weights for P-Net ...
# [INFO] Loading weights for R-Net ...
# [INFO] Loading weights for o-Net ...

# %%
# raw_img = cv2.imread(os.path.join(train_dir, 'road155.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road198.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road202.png')) # --> True but quite abit of overlapping boxes
# raw_img = cv2.imread(os.path.join(train_dir, 'road215.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road797.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road655.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road420.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road123.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road109.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road108.png')) # --> False, target too small
# raw_img = cv2.imread(os.path.join(train_dir, 'road99.png')) # --> Very true
# raw_img = cv2.imread(os.path.join(train_dir, 'road90.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road282.png')) # --> False, too blurry
# raw_img = cv2.imread(os.path.join(train_dir, 'road282.png')) # --> False, too blurry
# raw_img = cv2.imread(os.path.join(train_dir, 'road147.png')) # --> True
# raw_img = cv2.imread(os.path.join(train_dir, 'road585.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road595.png'))
raw_img = cv2.imread('test/test4.jpg')
raw_img = cv2.cvtColor(raw_img, cv2.COLOR_BGR2RGB)

def get_bboxes_pnet(raw_img, threshold=0.5, nms_threshold=0.5,
                    scale_factor=2.0, min_img_size = 48, padding = 0.15, visualize=False):
    '''
        
    '''
    H, W = raw_img.shape[:2]
    images = [raw_img]
    current_h, current_w = raw_img.shape[:2]
    
    ### 1. Get image pyramid ###
    while(current_h > min_img_size and current_w > min_img_size):
        current_h = int(current_h / scale_factor)
        current_w = int(current_w / scale_factor)

        if(current_w < min_img_size or current_h < min_img_size) : break

        image = cv2.resize(raw_img, (current_w, current_h))
        images.append(image)

    ### 2. Get bounding boxes from each image in the pyramid ###
    boxes = []
    conf_maps_viz = []
    for i, image in enumerate(images):
        if(i == 0): scale = 1
        else : scale = scale_factor ** i

        img = (image - 127.5) / 127.5
        height, width = image.shape[:2]

        predictions = pnet.predict(np.array([img]))
        features_shape = predictions[1][0].shape[:2]

        scale_w = width / features_shape[1]
        scale_h = height / features_shape[0]

        bboxes = predictions[1][0]
        raw_bboxes = bboxes
        confidence = predictions[0][0]

        ### Getting confidence map ###
        conf_map = confidence[:, :, 1]
        conf_map[conf_map > threshold] = 1.0
        conf_map[conf_map <= threshold] = 0
        conf_map = (conf_map * 255).astype(np.uint8)
        contours, hierarchy = cv2.findContours(conf_map, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        
        conf_maps_viz.append(conf_map)
        
        for contour in contours:
            rect = cv2.boundingRect(contour)
            x, y, w, h = (rect * np.array([W/conf_map.shape[1],H/conf_map.shape[0],W/conf_map.shape[1],H/conf_map.shape[0] ])).astype(int)

            x -= min(int(padding * w), x)
            y -= min(int(padding * h), y)
            w += 2*int(padding * w)
            h += 2*int(padding * h)
            if(w * h < (W * H)/64): continue
            boxes.append([x,y,w,h])
    
    ### Performing nms ###
    final_boxes = []
    pick = __nms(np.array(boxes), np.ones((len(boxes))), nms_threshold, 'Min')
    for i in range(len(boxes)):
        final_boxes.append(boxes[i])
        
    crops = []
    if(visualize):
        fig, ax = plt.subplots(1, len(conf_maps_viz) + 1, figsize=(5*(len(conf_maps_viz) + 1), 5))
        for i in range(len(conf_maps_viz)):
            current_size = (H // (scale_factor ** i),W // (scale_factor**i))
            ax[i].imshow(conf_maps_viz[i])
            ax[i].set_title(f'Stage {i+1} {current_size}')
        
    raw_img_copy = raw_img.copy()
    for (x, y, w, h) in final_boxes:
        cv2.rectangle(raw_img_copy, (x,y), (x+w, y+h), (0,0,255),2)
        crops.append([(x,y,w,h), raw_img[y:y+h, x:x+w]])
            
    if(visualize):
        plt.imshow(raw_img_copy)
        plt.show()
        
    return final_boxes, crops
        
boxes, crops = get_bboxes_pnet(raw_img, visualize=True)

# %%
raw_img = cv2.imread('test/test9.jpg')
raw_img = cv2.cvtColor(raw_img, cv2.COLOR_BGR2RGB)
boxes, crops = get_bboxes_pnet(raw_img, visualize=True)

raw_img_copy = raw_img.copy()
boxes = []

n_frames = 0
start = time.time()
for i in crops:
    n_frames += 1
    crop = i[1]
    (x, y, w, h) = i[0]
    H, W = crop.shape[:2]
    img = cv2.resize(crop, (input_dim*4, input_dim*4))
    img = (img - 127.5) / 127.5
    
    prediction = onet.predict(np.array([img]))
    confidence = prediction[0][0][0][0]
    
    label = np.argmax(confidence)
    confidence = confidence[np.argmax(confidence)]
    
    bbox = prediction[1][0][0][0]
    if(confidence < 0.98 or label == 0):continue
    
    x_,y_,w,h = (bbox * np.array([W, H, W, H])).astype('int')
    x+=x_
    y+=y_
    
    boxes.append([x, y, w, h])
end = time.time()
print(f'FPS : {n_frames/(end - start)}')

pick = __nms(np.array(boxes), np.ones((len(boxes))), 0.3, 'Max')
for i in pick:
    x, y, w, h = boxes[i]
    raw_img_copy = cv2.rectangle(raw_img_copy, (x, y), (x+w, y+h), (0,255,0), 3)
    raw_img_copy = cv2.putText(raw_img_copy, f'{confidence:.2f}', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 3)
    
plt.imshow(raw_img_copy)
plt.show()
# Out:
# FPS : 19.357239170415816
